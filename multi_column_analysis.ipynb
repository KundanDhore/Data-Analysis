# %%
import pandas as pd
import numpy as np

# %%
 df = pd.read_csv('playstore.csv')

# %%
df.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana          FAMILY     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    review  size  type  installs  price content_rating
# 0     159    19  Free     10000      0       Everyone
# 1     974    14  Free    500000      0       Everyone
# 2   87510     8  Free   5000000      0       Everyone
# 3  215644    25  Free  50000000      0           Teen
# 4     967     2  Free    100000      0       Everyone

# %%
## 1) converting data frame to an array

# %%
data = df.values

# %%
data.shape
# Out:
# (9648, 9)

# %%
data[3]
# Out:
# array(['Sketch - Draw & Paint', 'ART_AND_DESIGN', 4.5, 215644, 25, 'Free',
#        50000000, 0, 'Teen'], dtype=object)

# %%
## Slicing Array

# %%
data[0:5,0:3]
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1],
#        ['Coloring book moana', 'FAMILY', 3.9],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7],
#        ['Sketch - Draw & Paint', 'ART_AND_DESIGN', 4.5],
#        ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', 4.3]],
#       dtype=object)

# %%
##3) Analyse - Print all apps name which comes under ART_AND_DESIGN

# %%
df.head()
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana          FAMILY     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    review  size  type  installs  price content_rating
# 0     159    19  Free     10000      0       Everyone
# 1     974    14  Free    500000      0       Everyone
# 2   87510     8  Free   5000000      0       Everyone
# 3  215644    25  Free  50000000      0           Teen
# 4     967     2  Free    100000      0       Everyone

# %%
for i in data:
    if(i[1] == 'ART_AND_DESIGN'):
        print(i[0])
# Out:
# Photo Editor & Candy Camera & Grid & ScrapBook
# U Launcher Lite – FREE Live Cool Themes, Hide Apps
# Sketch - Draw & Paint
# Pixel Draw - Number Art Coloring Book
# Paper flowers instructions
# Smoke Effect Photo Maker - Smoke Editor
# Infinite Painter
# Garden Coloring Book
# Kids Paint Free - Drawing Fun
# Text on Photo - Fonteee
# Name Art Photo Editor - Focus n Filters
# Tattoo Name On My Photo Editor
# Mandala Coloring Book
# 3D Color Pixel by Number - Sandbox Art Coloring
# Photo Designer - Write your name with shapes
# 350 Diy Room Decor Ideas
# FlipaClip - Cartoon animation
# ibis Paint X
# Logo Maker - Small Business
# Boys Photo Editor - Six Pack & Men's Suit
# Superheroes Wallpapers | 4K Backgrounds
# HD Mickey Minnie Wallpapers
# Harley Quinn wallpapers HD
# Colorfit - Drawing & Coloring
# Animated Photo Editor
# Pencil Sketch Drawing
# Easy Realistic Drawing Tutorial
# Pink Silver Bow Keyboard Theme
# Art Drawing Ideas
# Anime Manga Coloring Book
# Easy Origami Ideas
# ...

# %%
## 4) analyse all the details of the application that comes under Dating

# %%
for i in data:
    if(i[1] == 'DATING'):
        print('-'*30)
        print("Name     : ",i[0])
        print("Rating   : ",i[2])
        print("Reviews  : ",i[3])
        print("Size     : ",i[4])
        print("Installs : ",i[5])
        print("type     : ",i[6])
        print("Price    : ",i[7])
        print("content r: ",i[8])
        print('-'*30)
# Out:
# ------------------------------
# Name     :  Moco+ - Chat, Meet People
# Rating   :  4.2
# Reviews  :  1546
# Size     :  10
# Installs :  Paid
# type     :  10000
# Price    :  299
# content r:  Mature 17+
# ------------------------------
# ------------------------------
# Name     :  Truth or Dare Pro
# Rating   :  4.4
# Reviews  :  0
# Size     :  20
# Installs :  Paid
# type     :  50
# Price    :  111
# content r:  Teen
# ------------------------------
# ------------------------------
# Name     :  Private Dating, Hide App- Blue for PrivacyHider
# Rating   :  4.4
# Reviews  :  0
# Size     :  1
# Installs :  Paid
# type     :  100
# Price    :  224
# content r:  Everyone
# ------------------------------
# ------------------------------
# Name     :  Ad Blocker for SayHi
# Rating   :  4.4
# Reviews  :  4
# Size     :  1
# Installs :  Paid
# type     :  100
# Price    :  299
# content r:  Teen
# ------------------------------
# ------------------------------
# ...

# %% [markdown]
# ### 5) Search application based on the title

# %%
title = "fitness"
n = 1
for i in data:
    if title.lower() in i[0].lower():
        print(n,". ",i[0])
        n +=1
# Out:
# 1 .  30 Day Fitness Challenge - Workout at Home
# 2 .  Lose Belly Fat-Home Abs Fitness Workout
# 3 .  Calorie Counter - MyFitnessPal
# 4 .  Abs Workout - 30 Days Fitness App for Six Pack Abs
# 5 .  Keep Trainer - Workout Trainer & Fitness Coach
# 6 .  PumpUp — Fitness Community
# 7 .  Workout Trainer: fitness coach
# 8 .  Workout Tracker & Gym Trainer - Fitness Log Book
# 9 .  Freeletics: Personal Trainer & Fitness Workouts
# 10 .  Nike Training Club - Workouts & Fitness Plans
# 11 .  Daily Workouts - Exercise Fitness Routine Trainer
# 12 .  Google Fit - Fitness Tracking
# 13 .  Sworkit: Workouts & Fitness Plans
# 14 .  Map My Fitness Workout Trainer
# 15 .  Daily Yoga - Yoga Fitness Plans
# 16 .  Simply Yoga - Fitness Trainer for Workouts & Poses
# 17 .  Sworkit Kids - Fitness Meets Fun
# 18 .  Daily Ab Workout - Core & Abs Fitness Exercises
# 19 .  Abs workout - 21 Day Fitness Challenge
# 20 .  Fitness Dance for Zum.ba Workout Exercise
# 21 .  BF Scale Health Fitness Tool
# ...

# %%
## 6) print app name details with rating 5

# %%
c = 1
for i in data:
    if(i[2]==5):
        print(str(c)+ '.',i[0])
        c +=1
# Out:
# 1. Hojiboy Tojiboyev Life Hacks
# 2. American Girls Mobile Numbers
# 3. Awake Dating
# 4. Spine- The dating app
# 5. Girls Live Talk - Free Text and Video Chat
# 6. Online Girls Chat Group
# 7. Speeding Joyride & Car Meet App
# 8. SUMMER SONIC app
# 9. Prosperity
# 10. Mindvalley U Tallinn 2018
# 11. Eternal life
# 12. Super Hearing Secret Voices Recorder PRO
# 13. FHR 5-Tier 2.0
# 14. Sway Medical
# 15. Labs on Demand
# 16. Dermatology Atlas (Colored & Illustrative)
# 17. Tablet Reminder
# 18. Galaxies of Hope
# 19. KBA-EZ Health Guide
# 20. FoothillsVet
# 21. PrimeDelivery
# 22. You're an Anime
# 23. Anatomy & Physiology Vocabulary Exam Review App
# 24. NCLEX Multi-topic Nursing Exam Review-Quiz & notes
# 25. Basics of Orthopaedics
# 26. Clinic Doctor EHr
# 27. 420 BZ Budeze Delivery
# 28. BP Journal - Blood Pressure Diary
# 29. Zen Leaf
# 30. ADS-B Driver
# 31. P-Home for KLWP
# 32. Android P Style Icon Pack
# 33. R Programing Offline Tutorial
# 34. Easy Hotspot Ad Free
# ...

# %% [markdown]
# ### 7) list all the paid apps in ART_AND_DESIGN catergory

# %%
for i in data:
    if(i[5]=='Paid' and i[1]=="ART_AND_DESIGN" and ):
        print(i[0])
# Out:
# X Launcher Pro: PhoneX Theme, OS11 Control Center
# X Launcher Pro - IOS Style Theme & Control Center
# X Launcher Prime: With OS Style Theme & No Ads

# %% [markdown]
# ### 8) List all the paid GAMES with rating 5

# %%
for i in data:
    if(i[5]=='Paid' and i[1]=="GAME" and i[2] == 5):
        print(i[0],"-",i[2])
# Out:
# Ra Ga Ba - 5.0
# 211:CK - 5.0
# Santa's Monster Shootout DX - 5.0
# Mu.F.O. - 5.0

# %%
### 9) List all free apps with 10000+ reviews, 100000+ installs, free for everyone

# %%
for i in data:
    if(i[5]=='Paid' and i[3]>10000 and i[6]>100000 and i[8]=='Everyone'):
        print('-'*30)
        print("Name     : ",i[0])
        print("Reviews  : ",i[3])
        print("Installs : ",i[5])
        print("content r: ",i[8])
        print('-'*30)
# Out:
# ------------------------------
# Name     :  Toca Life: City
# Reviews  :  31100
# Installs :  Paid
# content r:  Everyone
# ------------------------------
# ------------------------------
# Name     :  Facetune - For Free
# Reviews  :  49553
# Installs :  Paid
# content r:  Everyone
# ------------------------------
# ------------------------------
# Name     :  Beautiful Widgets Pro
# Reviews  :  97890
# Installs :  Paid
# content r:  Everyone
# ------------------------------
# ------------------------------
# Name     :  HD Widgets
# Reviews  :  58614
# Installs :  Paid
# content r:  Everyone
# ------------------------------
# ------------------------------
# Name     :  Weather Live
# Reviews  :  76593
# Installs :  Paid
# content r:  Everyone
# ------------------------------
# ------------------------------
# Name     :  Cut the Rope GOLD
# Reviews  :  61264
# Installs :  Paid
# content r:  Everyone
# ------------------------------
# ------------------------------
# ...

# %%
df
# Out:
#                                                     app             category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana               FAMILY
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9643                                   Sya9a Maroc - FR               FAMILY
# 9644                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9645                             Parkinson Exercices FR              MEDICAL
# 9646                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9647      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...
